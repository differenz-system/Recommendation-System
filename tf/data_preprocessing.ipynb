# %%
import pandas as pd

# %%
path='dataset/site1/productdata.csv'

tensor_df=pd.read_csv(path)

tensor_df.drop(['Unnamed: 0','selling_price','product_rating','product_description','product_cat_id','soup'],axis=1,inplace=True)
tensor_df.drop(['categories','product_cat_name','sale_percentage','regular_price','product_parent_cat'],axis=1,inplace=True)
tensor_df['product_id']=tensor_df['product_id'].astype('str')
tensor_df
# Out:
#       product_id                                       product_name  \
# 0          95781             Garlic Oil - Vegetarian Capsule 500 mg
# 1          95782                              Water Bottle - Orange
# 2          95783                     Brass Angle Deep - Plain, No.2
# 3          95784  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          95785                 Creme Soft Soap - For Hands & Body
# ...          ...                                                ...
# 23445     119226                Jowar Flakes - With Honey & Almonds
# 23446     119227                             Mayonnaise - Olive Oil
# 23447     119228         Tooth Brush Pro Health - Gum Care (Medium)
# 23448     119229                  Chocolate Peanut Butter - Crunchy
# 23449     119230             Perfume Body Spray - Tag Her For Women
#
#                 short_description
# 0               ['hairoil&serum']
# 1         ['water&fridgebottles']
# 2                ['lamp&lampoil']
# ...

# %% [raw]
# path_to_save='dataset/tf_data/tensor_data.csv'
# tensor_df=tensor_df.to_csv(path_to_save)
